# %%
import importlib
import sea_level_predictor  # or your exact filename, no `.py`

importlib.reload(sea_level_predictor)
# Out:
# <module 'sea_level_predictor' from 'C:\\Users\\srinivas\\Data_Analysis_Project 5\\sea_level_predictor.py'>

# %%
import unittest
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'epa-sea-level.csv',
#  'main.ipynb',
#  'main.py',
#  'sea_level_plot.png',
#  'sea_level_predictor.ipynb',
#  'sea_level_predictor.py',
#  'sea_level_predictor1.ipynb',
#  'test_module.py',
#  '__pycache__']

# %%
import unittest
import test_module

suite = unittest.TestLoader().loadTestsFromModule(test_module)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_plot_data_points (test_module.LinePlotTestCase) ... ok
# test_plot_labels (test_module.LinePlotTestCase) ... ok
# test_plot_lines (test_module.LinePlotTestCase) ... ok
# test_plot_title (test_module.LinePlotTestCase) ... ok
#
# ----------------------------------------------------------------------
# Ran 4 tests in 0.641s
#
# OK
# <unittest.runner.TextTestResult run=4 errors=0 failures=0>
